# %%
print("Hello Man~")
print("Really?")
print("Please...")
print("Why ... ?")
print("From time to time")
print("333")

# %%
print('Action이 추가했어요!')

# %%
print('Action이 추가했어요!')

# %%
print('Action이 추가했어요!')

# %%
print('Action이 추가했어요!')

# %%
print('Action이 추가했어요!')
